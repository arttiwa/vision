# %%
import os 
import numpy 
import cv2

path = r"C:\Users\thiwa\OneDrive\Desktop\Picture"

for filename in os.listdir(path):
    if filename.endswith(".jpg"):  # Check if the file is a JPG image
        # Construct full file path
        file_path = os.path.join(path, filename)
        # Read the image
        image = cv2.imread(file_path)
        # Check if image has been loaded properly
        if image is not None:
            # Display the image
            cv2.imshow('Image', image)
            # Wait for a key press to close the image window
            cv2.waitKey(0)
            cv2.destroyAllWindows()
        else:
            print(f"Failed to load image: {filename}")
    else:
        continue  # Skip non-jpg files

# When all images have been processed
cv2.destroyAllWindows()

# %%
import os
import cv2
import pytesseract

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

path = r"C:\Users\thiwa\OneDrive\Desktop\Picture\test_up2"

for filename in os.listdir(path):
    if filename.endswith(".jpg"):
        file_path = os.path.join(path, filename)
        image = cv2.imread(file_path)
        
        if image is not None:
            # Convert to grayscale
            gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            # Apply thresholding

            # gray_image = cv2.resize(gray_image, None, fx=2.0, fy=2.0, interpolation=cv2.INTER_LINEAR)
            # thresh_image = cv2.adaptiveThreshold(gray_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

            
            _, thresh_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            # Configuration for OCR: Using only numbers, OEM and PSM modes
            # custom_config = r'--oem 3 --psm  -c tessedit_char_whitelist=0123456789'
            
            
            custom_config = r'--oem 3 --psm 6'
            text = pytesseract.image_to_string(thresh_image, config=custom_config)
            print(f"Extracted Text from {filename}:\n{text}\n")
            
            # Optionally, display the image
            cv2.imshow('Image', thresh_image)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
        else:
            print(f"Failed to load image: {filename}")
    else:
        continue

cv2.destroyAllWindows()
# Out:
# Extracted Text from 230682 - Copy.jpg:
# . y su ;
# = Mu army wachiswnn AND ee CATE oF
# = RP
# 2 ne ade a Ye, rad fae y Pray
# = PAY oF yo a
# Bim 0 at mateo 5 Se) _
# = BAHT
# : _ oo . Be yrs
# = suImisnisinasusra dia (wistU) '
#
# BUR sirmnernsinasusne gto wn
# Bo nmr
# 310065 nuuasathroat waaaditu iannaulee nanny
# i THANON SONG PRAPHA BRANCH
# wGadUadanyennd Toqnewavioussina Ave ye wo
# £  awursodnsuldrutt wS naludersssudeubad wwe -
# a sGmaud CHEQUE NO. anutaufl BRANCH NO. sauffdeud ACCOUNT NOL
# 30 "?hb26L36"OhaOL35 29520079830"

# %%
import os
import cv2
import pytesseract

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

path = r"C:\Users\thiwa\OneDrive\Desktop\Picture\test_up2"

for filename in os.listdir(path):
    if filename.endswith(".jpg"): 
        file_path = os.path.join(path, filename)
        
        image = cv2.imread(file_path)
        if image is not None:
            gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            custom_config = r'--oem 3 --psm 7 -c tessedit_char_whitelist=0123456789'

            text = pytesseract.image_to_string(gray_image)
            print(f"Extracted Text from {filename}:\n{text}\n")
            cv2.imshow('Image', gray_image)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
        else:
            print(f"Failed to load image: {filename}")
    else:
        continue  

# When all images have been processed
cv2.destroyAllWindows()
# Out:
# Extracted Text from 230682 - Copy.jpg:
# Sua [|
# DATE J
# 9/0 af
#
# tne aun woeiuingqns AND
#
# svn AP ae? Ae 8 (Ssin
#
# PAY
#
# uan
# BAHT
#
# 00 NN
#
# ie" AE SEE La a) aun)
#
# B= 5x95
#
# Ubb = Earrvenretnasioia Safa (uHAwU)
#
# /MBThanachart Bank Publie Company Limited
#
# =
# SS mnowerem
#
# 310/85 quunzalrem ural ammeter nqaone
#
# | THANON SONG PRAPHA BRANCH
#
# WWaduawaweysAnd TannenuarioUs:ina Av eje ~
# £  anursoinisudnun ws aldArsssuGeuiGaduwa
#
# ‘Gnvautt CHEQUE NO, anuniautt BRANCH NO. sauttdeyd ACCOUNT NO,
#
# "30 "?8h28438"0hi"0295 2352002963"

# %%
from PIL import Image, ImageDraw, ImageFont

# Create a blank white image
img = Image.new('RGB', (600, 200), color = (255, 255, 255))
draw = ImageDraw.Draw(img)

# Define the OCR-friendly font and size
font_path = r"C:\Users\thiwa\OneDrive\Desktop\Picture\micr-encoding\micrenc.ttf"  # Adjust path as needed
font = ImageFont.truetype(font_path, 40)

# Add text to the image
text = "1234567890 Aa Bb cc dd ee ff ghij"
draw.text((50, 50), text, font=font, fill=(0, 0, 0))

# Save the image
img.save('OCR_Test_Image1.png')

# Display the image (optional, requires a GUI environment)
img.show()

# %%
import pytesseract
from PIL import Image
import cv2

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Adjust for your path

# Load an image
image_path = r'C:\Users\thiwa\OneDrive\Desktop\Picture\test_up2\224248.jpg'
img = cv2.imread(image_path)

if img is not None:
    # Convert to grayscale (optional but recommended)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Use the specific trained data (e.g., 'mcr' for MICR reading)
    custom_config = r'-l mcr --psm 6'
    text = pytesseract.image_to_string(gray, config=custom_config)
    print("Extracted Text:", text)

    # Show the image
    cv2.imshow("Processed Image", gray)

    # Wait for any key to be pressed
    cv2.waitKey(0)

    # Destroy all OpenCV windows
    cv2.destroyAllWindows()
else:
    print("Error: Image not found or the path is incorrect")
# Out:
# Extracted Text: 9 b 588 8 d 3
# 2 d8 dd dddd2 d0 95 d5 d 0
# 5 45521
# 5 598 8130479 34 59088d65536dc 496 3 5009
# 5 dd b b b 0840 bb 0 b b
# 5 d a56d69151983126092
# 5 8dd
# 5 8 08 0 b d 5 bbd
# 0 ddaddcd dd 898800 dd 8
# 2 ddddd5ddddd
# 0 dddcddad
# dd dddd ddddd ddd
# 2 dddd0d
# 088889090000888 dddddd cdd 4 d
# 8 ddddddd ca 0021808955581000188898100 d
# 2 ddd dda d dddd dddd d dddd dadd d
# a 30 c 78 1284 38c011d013 5a 135100236 3c

# %%
import pytesseract
import cv2

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

image_path = r'C:\Users\thiwa\OneDrive\Desktop\Picture\test_up2\224248.jpg'
img = cv2.imread(image_path)

if img is not None:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Use the specific trained data (e.g., 'mcr' for MICR reading)
    custom_config = r'-l mcr --psm 6'
    text = pytesseract.image_to_string(gray, config=custom_config)
    
    lines = text.splitlines()
    last_line = lines[-1] if lines else ''  # Ensure there's at least one line

    # print("Extracted Line:", lines)
    print("Extracted Last Line:", last_line)

    

    # Show the image
    cv2.imshow("Processed Image", gray)
    # Wait for any key to be pressed
    cv2.waitKey(0)
    # Destroy all OpenCV windows
    cv2.destroyAllWindows()
else:
    print("Error: Image not found or the path is incorrect")
# Out:
# Extracted Last Line: a 30 c 78 1284 38c011d013 5a 135100236 3c
