# %%
# !pip install pyautogui
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pyautogui
import time
import math

# Define the number of rows and calculate the number of pages
rows = 85
endloop = 0
page = math.ceil(rows / 15)
print(f'total page == {page}')

currentPage = 1
i = 1

while i <= 16:
    
    if endloop == rows:
        print(f'end at *** {endloop}')
        break 
    
    # if currentPage > 1 :
    #     # pagination
    #     time.sleep(0.5)
    #     print(f' CHANGE PAGE erery times > 2 >>>{currentPage}.{i}<<<')
    #     pyautogui.moveTo(x=1802, y=1041)

    #     if currentPage == 2:
    #         time.sleep(0.1)
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
           
    #     if currentPage == 3:
    #         time.sleep(0.1)
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #     if currentPage == 4:
    #         time.sleep(0.1)
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #     if currentPage == 5:
    #         time.sleep(0.1)
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
           
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #     if currentPage == 6:
    #         time.sleep(0.1)
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #     if currentPage == 7:
    #         time.sleep(0.1)
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
           
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')
            
    #         pyautogui.click()
    #         time.sleep(0.1)
    #         print(f'-------------------- click at {currentPage}.{i} ')        
    
    # else :
    #     print('nothing')
    
    # if i == 4:
    #     if currentPage == page:
    #         print(f'>>>{currentPage}.{i}<<<END page {currentPage}')
    #         break
        
    #     # print(f'CHANGE PAGE+++ {currentPage}')
    #     # pyautogui.moveTo(x=1802, y=1041)
    #     print(f'>>>{currentPage}.{i}<<<currentPage  {currentPage}')
    #     i = 1
    #     currentPage += 1 
    #     time.sleep(0.5)

    elif i != 4:
        time.sleep(0.5)
        # Locate the store image and proceed with the process
        position = pyautogui.locateCenterOnScreen('./img/store.png', confidence=0.8)

        if position:
            # print(f'store found at {position}')
            pyautogui.moveTo(position.x, position.y + (i * 42))  
            print(f'>>>{currentPage}.{i}<<<store{i} clicked at {position.x, position.y + (i * 42)}')
            pyautogui.click()
            time.sleep(3)

            # Locate the singel_save image and proceed
            position_singel_save = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)
            if position_singel_save:
                print(f'>>>{currentPage}.{i}<<<singel_save{i} found at {position_singel_save}')
                pyautogui.moveTo(position_singel_save)
                pyautogui.click()
                time.sleep(0.5)
            
                # Locate the cat image and proceed
                position_cat = pyautogui.locateCenterOnScreen('./img/cat.png', confidence=0.8)
                if position_cat:
                    # print(f'cat found at {position}')
                    pyautogui.moveTo(position_cat)
                    pyautogui.click()
                    time.sleep(0.2)
                    
                    # back
                    pyautogui.moveTo(x=25, y=76)
                    pyautogui.click()
                    
                    i += 1
                    endloop += 1 
                    print(f'>>>{currentPage}.{i}<<<easy {i} at --> {endloop}')
                    time.sleep(3)
                    
                    
                else:
                    print('cat not found')
                    time.sleep(1)
                    break
            else:
                print('singel_save not found')
                time.sleep(1)
                break
        else:
            print('store not found')
            time.sleep(1)
            break


position_singel_save_last = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)
if position_singel_save_last:
    print(f'position_singel_save_last found at {position_singel_save_last}')
    pyautogui.moveTo(position_singel_save_last)
    pyautogui.click()
    time.sleep(0.5)
# Out:
# total page == 6
# >>>1.1<<<store1 clicked at (370, 402)
# >>>1.1<<<singel_save1 found at Point(x=1798, y=404)
# >>>1.2<<<easy 2 at --> 1
# >>>1.2<<<store2 clicked at (370, 444)
# >>>1.2<<<singel_save2 found at Point(x=1797, y=404)
# >>>1.3<<<easy 3 at --> 2
# >>>1.3<<<store3 clicked at (370, 486)
# >>>1.3<<<singel_save3 found at Point(x=1797, y=404)
# >>>1.4<<<easy 4 at --> 3
# >>>1.4<<<currentPage  1
#  CHANGE PAGE erery times > 2 >>>2.1<<<
# -------------------- click at 2.1
# >>>2.1<<<store1 clicked at (370, 402)
# >>>2.1<<<singel_save1 found at Point(x=1797, y=404)
# >>>2.2<<<easy 2 at --> 4
#  CHANGE PAGE erery times > 2 >>>2.2<<<
# -------------------- click at 2.2
# >>>2.2<<<store2 clicked at (370, 444)
# >>>2.2<<<singel_save2 found at Point(x=1798, y=404)
# >>>2.3<<<easy 3 at --> 5
#  CHANGE PAGE erery times > 2 >>>2.3<<<
# -------------------- click at 2.3
# >>>2.3<<<store3 clicked at (370, 486)
# >>>2.3<<<singel_save3 found at Point(x=1797, y=404)
# ...

# %%
pyautogui.position()
# Out:
# next found at Point(x=1832, y=1041)

# %%
pyautogui.moveTo(x=370, y=990)
pyautogui.moveTo(x=1802, y=1041)

# %%
import pyautogui
import time
import math
from pyautogui import ImageNotFoundException



# Define the number of rows and calculate the number of pages
rows = 85
inputrowsEP = 15

time.sleep(3)

rowsEP = inputrowsEP +1
endloop = 0
page = math.ceil(rows / rowsEP)
print(f'total page == {page}')

currentPage = 1
i = 1

while True:
    if endloop == rows:
        print(f'***********{endloop}*********')
        break
    
    # cut page
    if i == rowsEP:
        time.sleep(0.5)
        i = 1
        currentPage += 1
        time.sleep(0.5)
        print(f'{currentPage}>>>>>>>>changedPage<<<<<<<<')
    else:
        time.sleep(0.5)
        # Locate the store image and proceed with the process
        position = pyautogui.locateCenterOnScreen('./img/store.png', confidence=0.8)

        if not position:
            print('store not found, retrying...')
            time.sleep(1)
            position = pyautogui.locateCenterOnScreen('./img/store.png', confidence=0.8)
            
        if position:
            pyautogui.moveTo(position.x, position.y + (i * 42))
            # print(f'>>>{currentPage}.{i}<<<store{i} clicked at {position.x, position.y + (i * 42)}')
            pyautogui.click()
            time.sleep(1)

            # Locate the singel_save image and proceed
            position_singel_save = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)
            
            if not position_singel_save:
                print('position_singel_save not found, retrying...')
                time.sleep(3)
                position_singel_save = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)
            
            if position_singel_save:
                # print(f'>>>{currentPage}.{i}<<<singel_save{i} found at {position_singel_save}')
                pyautogui.moveTo(position_singel_save)
                pyautogui.click()
                time.sleep(0.5)

                # Locate the cat image and proceed
                position_cat = pyautogui.locateCenterOnScreen('./img/cat.png', confidence=0.8)
                
                
                if not position_cat:
                    print('position_singel_save not found, retrying...')
                    time.sleep(3)
                    position_cat = pyautogui.locateCenterOnScreen('./img/cat.png', confidence=0.8)
            
                if position_cat:
                    pyautogui.moveTo(position_cat)
                    pyautogui.click()
                    time.sleep(0.2)

                    # back
                    pyautogui.moveTo(x=25, y=76)
                    pyautogui.click()
                    
                    print(f'             ////finish//// {currentPage}.{i}<<<easy {i} at --> {endloop}')
                    i += 1
                    endloop += 1
                    time.sleep(3)
                else:
                    print('cat not found')
                    time.sleep(1)
                    break
            else:
                print('singel_save not found')
                time.sleep(1)
                break
        else:
            print('store not found')
            time.sleep(1)
            break

    if currentPage > 1 and i != rowsEP:
        # pagination
        time.sleep(0.5)
        print(f' CHANGED PAGE -------------------------------------------------- >>>{currentPage}.{i}<<<')
        # pyautogui.moveTo(x=1802, y=1041)

        click_count = currentPage - 1
        for _ in range(click_count):
            print(f'        move!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!{click_count}!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! {currentPage}.{i} ')
            time.sleep(0.1)
            pyautogui.moveTo(x=1802, y=1041)
            pyautogui.click()
            # print(f'----------{click_count}---------- click at {currentPage}.{i} ')
            time.sleep(0.1)
    else:
        print(f'          ---------{i}end loop for first page----------')


# Final singel_save click
position_singel_save_last = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)

if not position_singel_save_last:
    print('position_singel_save_last not found, retrying...')
    time.sleep(3)
    position_singel_save_last = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)
            

if position_singel_save_last:
    print(f'position_singel_save_last found at {position_singel_save_last}')
    pyautogui.moveTo(position_singel_save_last)
    pyautogui.click()
    time.sleep(0.5)
# Out:
# total page == 6
#              ////finish//// 1.1<<<easy 1 at --> 0
#           ---------2end loop for first page----------
#              ////finish//// 1.2<<<easy 2 at --> 1
#           ---------3end loop for first page----------
#              ////finish//// 1.3<<<easy 3 at --> 2
#           ---------4end loop for first page----------
#              ////finish//// 1.4<<<easy 4 at --> 3
#           ---------5end loop for first page----------
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     171 try:
# --> 172     return wrappedFunction(*args, **kwargs)
#     173 except pyscreeze.ImageNotFoundException:
#
# ...

# %%
import pyautogui
import time
import math

# Define the number of rows and calculate the number of pages
rows = 85
endloop = 0
page = math.ceil(rows / 15)
print(f'total pages = {page}')

currentPage = 1
i = 1

while endloop < rows:
    # Locate the store image and proceed with the process
    position = pyautogui.locateCenterOnScreen('./img/store.png', confidence=0.8)

    if position:
        pyautogui.moveTo(position.x, position.y + (i * 42))
        print(f'>>> {currentPage}.{i} <<< store {i} clicked at {position.x, position.y + (i * 42)}')
        pyautogui.click()
        time.sleep(3)

        # Locate the singel_save image and proceed
        position_singel_save = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)
        if position_singel_save:
            print(f'>>> {currentPage}.{i} <<< singel_save {i} found at {position_singel_save}')
            pyautogui.moveTo(position_singel_save)
            pyautogui.click()
            time.sleep(0.5)

            # Locate the cat image and proceed
            position_cat = pyautogui.locateCenterOnScreen('./img/cat.png', confidence=0.8)
            if position_cat:
                pyautogui.moveTo(position_cat)
                pyautogui.click()
                time.sleep(0.2)

                # Back
                pyautogui.moveTo(x=25, y=76)
                pyautogui.click()

                i += 1
                endloop += 1
                print(f'>>> {currentPage}.{i} <<< easy {i} at --> {endloop}')
                time.sleep(3)
            else:
                print('cat not found')
                time.sleep(1)
                break
        else:
            print('singel_save not found')
            time.sleep(1)
            break
    else:
        print('store not found')
        time.sleep(1)
        break

    # Pagination handling
    if i == 4:
        if currentPage == page:
            print(f'>>> {currentPage}.{i} <<< END page {currentPage}')
            break

        print(f'>>> {currentPage}.{i} <<< currentPage {currentPage}')
        pyautogui.moveTo(x=1802, y=1041)
        
        # Click the pagination button only once
        pyautogui.click()
        time.sleep(1)  # Increase delay to allow the page to load completely
        
        i = 1
        currentPage += 1 

# Handle any remaining single save at the end
position_singel_save_last = pyautogui.locateCenterOnScreen('./img/singel_save.png', confidence=0.8)
if position_singel_save_last:
    print(f'position_singel_save_last found at {position_singel_save_last}')
    pyautogui.moveTo(position_singel_save_last)
    pyautogui.click()
    time.sleep(0.5)

print(f'Total processed items: {endloop}')
# Out:
# total pages = 6
# >>> 1.1 <<< store 1 clicked at (370, 402)
# >>> 1.1 <<< singel_save 1 found at Point(x=1797, y=404)
# >>> 1.2 <<< easy 2 at --> 1
# >>> 1.2 <<< store 2 clicked at (370, 444)
# >>> 1.2 <<< singel_save 2 found at Point(x=1798, y=404)
# >>> 1.3 <<< easy 3 at --> 2
# >>> 1.3 <<< store 3 clicked at (370, 486)
# >>> 1.3 <<< singel_save 3 found at Point(x=1798, y=404)
# >>> 1.4 <<< easy 4 at --> 3
# >>> 1.4 <<< currentPage 1
# >>> 2.1 <<< store 1 clicked at (370, 402)
# >>> 2.1 <<< singel_save 1 found at Point(x=1798, y=404)
# >>> 2.2 <<< easy 2 at --> 4
# >>> 2.2 <<< store 2 clicked at (370, 444)
# >>> 2.2 <<< singel_save 2 found at Point(x=1798, y=404)
# >>> 2.3 <<< easy 3 at --> 5
# >>> 2.3 <<< store 3 clicked at (370, 486)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[116], line 22
# ...

# %%
import pyautogui
import time
import math
from pyautogui import ImageNotFoundException

# Define the number of rows and calculate the number of pages
rows = 85
inputrowsEP = 15
nextCal = [42,43,42,43,42,42,42]


time.sleep(3)
average = sum(nextCal) / len(nextCal)

conDelay = 1
rowsEP = inputrowsEP + 1
endloop = 1
nextRow = round(average)
page = math.ceil(rows / rowsEP)
print(f'total page == {page}')

currentPage = 1
i = 1

def locate_image_with_retry(image_path, retries=1, confidence=0.8, delay=1):
    """Attempt to locate an image on the screen with retry logic."""
    for attempt in range(retries + 10):
        try:
            position = pyautogui.locateCenterOnScreen(image_path, confidence=confidence)
            print(f'finding..{image_path} at {attempt}')
            if position:
                return position
        except ImageNotFoundException:
            pass
        time.sleep(delay)
    return None

while True:
    if endloop == rows+1:
        print(f'***********{endloop}*********')
        break
    
    # cut page
    if i == rowsEP:
        time.sleep(0.5)
        i = 1
        currentPage += 1
        time.sleep(0.5)
        print(f'{currentPage}>>>>>>>>changedPage<<<<<<<<')
    else:
        time.sleep(0.5)

        # Locate the store image and proceed with the process
        position = locate_image_with_retry('./img/store.png', retries=1, confidence=0.8, delay=conDelay)

        if position:
            pyautogui.moveTo(position.x, position.y + (i * nextRow))
            pyautogui.click()
            time.sleep(1)

            # Locate the singel_save image and proceed
            position_singel_save = locate_image_with_retry('./img/singel_save.png', retries=1, confidence=0.8, delay=conDelay)

            if position_singel_save:
                pyautogui.moveTo(position_singel_save)
                pyautogui.click()
                time.sleep(0.5)

                # Locate the cat image and proceed
                position_cat = locate_image_with_retry('./img/cat.png', retries=1, confidence=0.8, delay=conDelay)

                if position_cat:
                    pyautogui.moveTo(position_cat)
                    pyautogui.click()
                    time.sleep(0.2)
                    pyautogui.click()
                    time.sleep(0.1)

                    # back
                    pyautogui.moveTo(x=25, y=76)
                    pyautogui.click()

                    print(f'             ////finish//// {currentPage}.{i}<<<easy {i} at --> {endloop}')
                    i += 1
                    endloop += 1
                    time.sleep(3)
                    # back slow refresh more delay 3 when its slowly
                else:
                    print('cat not found after retry')
                    break
            else:
                print('singel_save not found after retry')
                break
        else:
            print('store not found after retry')
            break

    if currentPage > 1 and i != rowsEP:
        # pagination
        time.sleep(0.5)
        print(f' CHANGED PAGE -------------------------------------------------- >>>{currentPage}.{i}<<<')

        click_count = currentPage - 1
        for _ in range(click_count):
            print(f'        move!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!{click_count}!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! {currentPage}.{i} ')
            time.sleep(0.1)
            pyautogui.moveTo(x=1802, y=1041)
            pyautogui.click()
            time.sleep(0.1)
    else:
        print(f'          ---------{i}end loop for first page----------')


# Final singel_save click
position_singel_save_last = locate_image_with_retry('./img/singel_save.png', retries=1, confidence=0.8, delay=conDelay)

if position_singel_save_last:
    print(f'position_singel_save_last found at {position_singel_save_last}')
    pyautogui.moveTo(position_singel_save_last)
    pyautogui.click()
    time.sleep(0.5)
else:
    print('position_singel_save_last not found after retry')
# Out:
# total page == 6
# finding.../img/store.png at 0
# finding.../img/singel_save.png at 0
# finding.../img/cat.png at 0
#              ////finish//// 1.1<<<easy 1 at --> 0
#           ---------2end loop for first page----------
# finding.../img/store.png at 0
# finding.../img/singel_save.png at 0
# finding.../img/cat.png at 0
#              ////finish//// 1.2<<<easy 2 at --> 1
#           ---------3end loop for first page----------
# finding.../img/store.png at 0
# finding.../img/singel_save.png at 0
# finding.../img/cat.png at 0
#              ////finish//// 1.3<<<easy 3 at --> 2
#           ---------4end loop for first page----------
# finding.../img/store.png at 0
# finding.../img/singel_save.png at 0
# finding.../img/cat.png at 0
#              ////finish//// 1.4<<<easy 4 at --> 3
#           ---------5end loop for first page----------
# finding.../img/store.png at 0
# finding.../img/singel_save.png at 0
# finding.../img/cat.png at 0
# ...

# %%
import pyautogui
import time
import math
from tkinter import Tk, Label, Entry, Button

def locate_image_with_retry(image_path, retries=1, confidence=0.8, delay=1):
    for attempt in range(retries + 10):
        try:
            position = pyautogui.locateCenterOnScreen(image_path, confidence=confidence)
            if position:
                return position
        except pyautogui.ImageNotFoundException:
            pass
        time.sleep(delay)
    return None

def start_process(rows, inputrowsEP, nextCal):
    rows = int(rows)
    inputrowsEP = int(inputrowsEP)
    nextCal = [int(x) for x in nextCal.split(',')]

    average = sum(nextCal) / len(nextCal)
    rowsEP = inputrowsEP + 1
    endloop = 1
    nextRow = round(average)
    page = math.ceil(rows / rowsEP)
    currentPage = 1
    i = 1

    while True:
        if endloop == rows:
            print(f'***********{endloop}*********')
            break
        
        if i == rowsEP:
            time.sleep(0.5)
            i = 1
            currentPage += 1
            time.sleep(0.5)
            print(f'{currentPage}>>>>>>>>changedPage<<<<<<<<')
        else:
            time.sleep(0.5)

            position = locate_image_with_retry('./img/store.png', retries=1, confidence=0.8, delay=1)
            if position:
                pyautogui.moveTo(position.x, position.y + (i * nextRow))
                pyautogui.click()
                time.sleep(1)

                position_singel_save = locate_image_with_retry('./img/singel_save.png', retries=1, confidence=0.8, delay=1)
                if position_singel_save:
                    pyautogui.moveTo(position_singel_save)
                    pyautogui.click()
                    time.sleep(0.5)

                    position_cat = locate_image_with_retry('./img/cat.png', retries=1, confidence=0.8, delay=1)
                    if position_cat:
                        pyautogui.moveTo(position_cat)
                        pyautogui.click()
                        time.sleep(0.2)
                        pyautogui.click()
                        time.sleep(0.1)

                        pyautogui.moveTo(x=25, y=76)
                        pyautogui.click()

                        print(f'////finish//// {currentPage}.{i}<<<easy {i} at --> {endloop}')
                        i += 1
                        endloop += 1
                        time.sleep(3)
                    else:
                        print('cat not found after retry')
                        break
                else:
                    print('singel_save not found after retry')
                    break
            else:
                print('store not found after retry')
                break

        if currentPage > 1 and i != rowsEP:
            time.sleep(0.5)
            print(f' CHANGED PAGE >>>{currentPage}.{i}<<<')

            click_count = currentPage - 1
            for _ in range(click_count):
                pyautogui.moveTo(x=1802, y=1041)
                pyautogui.click()
                time.sleep(0.1)

    position_singel_save_last = locate_image_with_retry('./img/singel_save.png', retries=1, confidence=0.8, delay=1)
    if position_singel_save_last:
        pyautogui.moveTo(position_singel_save_last)
        pyautogui.click()
        time.sleep(0.5)
    else:
        print('position_singel_save_last not found after retry')


def run_ui():
    window = Tk()
    window.title("Automation Tool")

    Label(window, text="Rows").grid(row=0, column=0)
    rows_entry = Entry(window)
    rows_entry.grid(row=0, column=1)

    Label(window, text="Input Rows Per Page").grid(row=1, column=0)
    inputrowsEP_entry = Entry(window)
    inputrowsEP_entry.grid(row=1, column=1)

    Label(window, text="Next Cal (comma-separated)").grid(row=2, column=0)
    nextCal_entry = Entry(window)
    nextCal_entry.grid(row=2, column=1)

    def on_submit():
        rows = rows_entry.get()
        inputrowsEP = inputrowsEP_entry.get()
        nextCal = nextCal_entry.get()
        start_process(rows, inputrowsEP, nextCal)

    Button(window, text="Start", command=on_submit).grid(row=3, column=1)

    window.mainloop()

if __name__ == "__main__":
    run_ui()
